# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
# use this also mainly.
https://www.ambitionbox.com/list-of-companies?page=1

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
requests.get('https://www.coingecko.com/',headers=headers).text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n<script src="/cdn-cgi/apps/head/gYtXOyllgyP3-Z2iKTP8rRWGBm4.js"></script><script async defer src="https://www.googleoptimize.com/optimize.js?id=GTM-W3CD992"></script>\n<meta charset="utf-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<link rel="shortcut icon" href="/favicon.ico">\n<link type="application/opensearchdescription+xml" rel="search" href="/OpensearchDescription.xml" />\n<title>Cryptocurrency Prices, Charts, and Crypto Market Cap | CoinGecko</title>\n<meta name="description" content="View top cryptocurrency prices live, crypto charts, market cap, and trading volume. Discover today’s new and trending coins, top crypto gainers and losers in the market." />\n\n\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n  new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n  j=d.createElement(s),dl=l!=\'dataLayer\'
# ...

# %% [markdown]
# # if response code is 403
#  - headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
#  -requests.get('url',headers=headers).text

# %%
webpage=requests.get('https://www.coingecko.com/',headers=headers).text

# %%
#creating beautifulSoup object

soup=BeautifulSoup(webpage,'lxml')

# %%
print (soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <script src="/cdn-cgi/apps/head/gYtXOyllgyP3-Z2iKTP8rRWGBm4.js">
#   </script>
#   <script async="" defer="" src="https://www.googleoptimize.com/optimize.js?id=GTM-W3CD992">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"cd4a6493ab","applicationID":"83495717","transactionName":"dV5dRBNcDlkEEU5SDF9fQB8IXQZQGQ==","queueTime":1,"applicationTime":549,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
soup.find_all('h1')
# Out:
# [<h1 class="tw-font-bold tw-text-gray-900 dark:tw-text-white dark:tw-text-opacity-87 md:tw-text-2xl tw-text-xl tw-mb-2 tw-mr-2 tw-pb-0 tw-mb-0" data-view-component="true">
#  Cryptocurrency Prices by Market Cap
#  </h1>]

# %%
soup.find_all('h1')[0].text
# Out:
# '\nCryptocurrency Prices by Market Cap\n'

# %%
soup.find_all('h2')
# Out:
# [<h2 class="tw-text-lg md:tw-text-2xl tw-font-bold tw-text-gray-900 dark:tw-text-white dark:tw-text-opacity-87">
#  Trending Coins
#  </h2>,
#  <h2 class="tw-font-bold tw-text-gray-900 dark:tw-text-white dark:tw-text-opacity-87 md:tw-text-xl tw-text-lg tw-text-xl md:tw-text-2xl tw-text-gray-900 dark:tw-text-opacity-87" data-view-component="true">
#  What is Crypto Market Cap?
#  </h2>,
#  <h2 class="tw-font-bold tw-text-gray-900 dark:tw-text-white dark:tw-text-opacity-87 md:tw-text-xl tw-text-lg tw-text-xl md:tw-text-2xl tw-text-gray-900 dark:tw-text-opacity-87" data-view-component="true">
#  How does CoinGecko Calculate Cryptocurrency Prices?
#  </h2>,
#  <h2 class="tw-font-bold tw-text-gray-900 dark:tw-text-white dark:tw-text-opacity-87 md:tw-text-xl tw-text-lg tw-text-xl md:tw-text-2xl tw-text-gray-900 dark:tw-text-opacity-87" data-view-component="true">
#  Where to Check Cryptocurrency Prices?
#  </h2>]

# %%
for i in soup.find_all('h2'):
    print(i.text)
# Out:
# Trending Coins
#
#
# What is Crypto Market Cap?
#
#
# How does CoinGecko Calculate Cryptocurrency Prices?
#
#
# Where to Check Cryptocurrency Prices?

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# Trending Coins
# What is Crypto Market Cap?
# How does CoinGecko Calculate Cryptocurrency Prices?
# Where to Check Cryptocurrency Prices?

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# The global cryptocurrency market cap today is $892 Billion, a 0.5% change in the last 24 hours.
#
# Read More
# Crypto market cap is the total value of all the coins of a particular cryptocurrency that have been mined or are in circulation. Market capitalization is used to determine the ranking of cryptocurrencies. The higher the market cap of a particular crypto coin, the higher its ranking and share of the market. Crypto market cap is calculated by multiplying the total number of coins in circulation by its current price. For instance, to calculate the market cap of Ethereum, all you need to do is multiply the total number of Ethereum in circulation by the current price of one Ethereum and you will get its market cap.
# Crypto market cap can be divided into three categories:
# ...

# %%
for i in soup.find_all('p'):
    print(i.text.strip())

# %%
soup.find_all('p',class_='dropdown-item tw-py-2')
# Out:
# []

# %%
soup.find_all('a')
# Out:
# [<a href="/en/privacy">Privacy Policy</a>,
#  <a data-action="app-flyer-banner#closeBanner">
#  <i class="far text-2xl font-light text-lite mt-1 fa-fa fa-times"></i>
#  </a>,
#  <a class="btn btn-primary" href="https://coingecko.app.link/lTInCXLGz4">Open App</a>,
#  <a data-action="app-flyer-banner#closeBanner">
#  <i class="far text-2xl font-light text-lite mt-1 fa-fa fa-times"></i>
#  </a>,
#  <a class="btn btn-primary" href="https://coingecko.app.link/lTInCXLGz4">Open App</a>,
# ...

# %%
len(soup.find_all('a'))
# Out:
# 437

# %%
len(soup.find_all('a',class_='Losers'))
# Out:
# 0

# %%
len(soup.find_all('p',class_='Categories'))
# Out:
# 0

# %%
len(soup.find_all('h2'))
# Out:
# 4

# %%
# finding target Data
results=soup.find('div',{'class':"coingecko.table"}).find("tbody").find_all("tr")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5464\2253431107.py in <module>
#       1 # finding target Data
# ----> 2 results=soup.find('div',{'class':"coingecko.table"}).find("tbody").find_all("tr")
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
webpage=requests.get('https://www.coingecko.com/').text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
#print(soup.prettify())

# %%
soup.find_all('h1')[0].text
# Out:
# '\nCryptocurrency Prices by Market Cap\n'

# %% [markdown]
# # TO FIND OUT NAMES OF THE COMPANIES

# %%
for i in soup.find_all('h2'):
  print(i.text.strip())
# Out:
# Trending Coins
# What is Crypto Market Cap?
# How does CoinGecko Calculate Cryptocurrency Prices?
# Where to Check Cryptocurrency Prices?

# %%
for i in soup.find_all('p'):
  print(i.text.strip())
# Out:
# The global cryptocurrency market cap today is $894 Billion, a 0.8% change in the last 24 hours.
#
# Read More
# Crypto market cap is the total value of all the coins of a particular cryptocurrency that have been mined or are in circulation. Market capitalization is used to determine the ranking of cryptocurrencies. The higher the market cap of a particular crypto coin, the higher its ranking and share of the market. Crypto market cap is calculated by multiplying the total number of coins in circulation by its current price. For instance, to calculate the market cap of Ethereum, all you need to do is multiply the total number of Ethereum in circulation by the current price of one Ethereum and you will get its market cap.
# Crypto market cap can be divided into three categories:
# ...

# %%
#for in soup.find_all('p'):
  #print(i.text.strip())

# %% [markdown]
# ## TO FIND OUT THE RATINGS

# %%
len(soup.find_all('p',class_='rating'))
# Out:
# 0

# %% [markdown]
# ## TO FIND OUT THE NUMBER OF REVIEWS

# %%
len(soup.find_all('a' , class_='review-count'))
# Out:
# 0

# %% [markdown]
# # CONSIDERING THE WHOLE CONTAINER

# %%
company=soup.find_all('div',class_='company-content-wrapper')

# %%
len(company)
# Out:
# 0

# %%
name=[]
rating=[]
reviews=[]
ctype=[]
hq=[]
how_old=[]
no_of_employee=[]

for i in company:

  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  reviews.append(i.find('a' , class_='review-count').text.strip())
  ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())

df=pd.DataFrame({'name':name,
   'rating':rating,
   'reviews':reviews,
   'company_type':ctype,
   'Head_Quarters':hq,
   'Company_Age':how_old,
   'No_of_Employee':no_of_employee,
   })

# %%
name
# Out:
# []

# %%
rating
# Out:
# []

# %%
reviews
# Out:
# []

# %%
ctype
# Out:
# []

# %%
hq
# Out:
# []

# %%
how_old
# Out:
# []

# %%
no_of_employee
# Out:
# []

# %%
df.shape
# Out:
# (0, 7)

# %% [markdown]
# # creating dataframe for all the pages

# %%
final=pd.DataFrame()
for j in range(1,1001):
  webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j)).text
  soup=BeautifulSoup(webpage,'lxml')
  company=soup.find_all('div',class_='company-content-wrapper')
  name=[]
  rating=[]
  reviews=[]
  ctype=[]
  hq=[]
  how_old=[]
  no_of_employee=[]

  for i in company:

    try:
       name.append(i.find('h2').text.strip())
    except:
       name.append(np.nan)

    try:
       rating.append(i.find('p',class_='rating').text.strip())
    except:
       rating.append(np.nan)
   
    try:

      reviews.append(i.find('a' , class_='review-count').text.strip())
    except:
      reviews.append(np.nan)

    try:

      ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    except:
      ctype.append(np.nan)
    try:

      hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
    except:
      hq.append(np.nan)
    
    try:

      how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
    except:
      how_old.append(np.nan)
    try:
      no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    except:
      no_of_employee.append(np.nan)
    

  df=pd.DataFrame({'name':name,
    'rating':rating,
    'reviews':reviews,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':how_old,
    'No_of_Employee':no_of_employee,
    })
  
  final=final.append(df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      71
# ---> 72     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73         af, socktype, proto, canonname, sa = res
#
# ~\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     953     addrlist = []
# --> 954     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     955         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
df.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5464\4274681390.py in <module>
# ----> 1 df.sample(5)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5444             weights = sample.preprocess_weights(self, weights, axis)
#    5445
# -> 5446         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    5447         result = self.take(sampled_indices, axis=axis)
#    5448
#
# ~\anaconda3\lib\site-packages\pandas\core\sample.py in sample(obj_len, size, replace, weights, random_state)
#     148             raise ValueError("Invalid weights: weights sum to zero")
#     149
# --> 150     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     151         np.intp, copy=False
#     152     )
#
# ...

# %%
df.shape
# Out:
# (0, 7)

# %%
final.shape
# Out:
# (0, 0)
