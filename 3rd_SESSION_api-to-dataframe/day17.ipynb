# %%
import pandas as pd
import requests

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg',
#    'genre_ids': [10749, 18],
#    'id': 851644,
#    'original_language': 'ko',
#    'original_title': '20세기 소녀',
#    'overview': "Yeon-du asks her best friend Bora to collect all the information she can about Baek Hyun-jin while she is away in the U.S. for heart surgery. Bora decides to get close to Baek's best friend, Pung Woon-ho first. However, Bora's clumsy plan unfolds in an unexpected direction. In 1999, a year before the new century, Bora, who turns seventeen, falls into the fever of first love.",
#    'popularity': 170.54,
#    'poster_path': '/od22ftNnyag0TTxcnJhlsu3aLoU.jpg',
#    'release_date': '2022-10-06',
#    'title': '20th Century Girl',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 290},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 86.518,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 16988},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 84.681,
#    'poster_path': '/hBcY0fE9pfXzvVaY4GKarweriG2.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 22748},
#   {'adult': False,
#    'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#    'genre_ids': [18, 80],
#    'id': 240,
#    'original_language': 'en',
#    'original_title': 'The Godfather Part II',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'popularity': 44.957,
#    'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#    'release_date': '1974-12-20',
#    'title': 'The Godfather Part II',
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 10293},
#   {'adult': False,
#    'backdrop_path': '/bxSBOAD8AuMHYMdW3jso9npAkgt.jpg',
#    'genre_ids': [10751, 18],
#    'id': 667257,
#    'original_language': 'es',
#    'original_title': 'Cosas imposibles',
#    'overview': 'Matilde is a woman who, after the death of her husband - a man who constantly abused her - finds her new best friend in Miguel, her young, insecure, disoriented and even dealer neighbor',
#    'popularity': 32.859,
#    'poster_path': '/t2Ew8NZ8Ci2kqmoecZUNQUFDJnQ.jpg',
#    'release_date': '2021-06-17',
#    'title': 'Impossible Things',
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 299},
#   {'adult': False,
#    'backdrop_path': '/vI3aUGTuRRdM7J78KIdW98LdxE5.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 23.31,
#    'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#    'release_date': '1995-10-19',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 3961},
#   {'adult': False,
#    'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#    'genre_ids': [18, 36, 10752],
#    'id': 424,
#    'original_language': 'en',
#    'original_title': "Schindler's List",
#    'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#    'popularity': 52.121,
#    'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#    'release_date': '1993-12-15',
#    'title': "Schindler's List",
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 13486},
#   {'adult': False,
#    'backdrop_path': '/aVFx1VtlOxR3v0ADEatalXOvwbu.jpg',
#    'genre_ids': [16, 14, 28],
#    'id': 620249,
#    'original_language': 'zh',
#    'original_title': '罗小黑战记',
#    'overview': 'In the bustling human world, spirits live peacefully with mankind. Luo Xiaohei, a young cat spirit, becomes a nomad after his forest home is destroyed. His natural talent soon attracts spirits and humans alike, but all of them have their own motivations.',
#    'popularity': 18.207,
#    'poster_path': '/aLv87NgRJUPkQ6sVLP72IisDdt4.jpg',
#    'release_date': '2019-08-27',
#    'title': 'The Legend of Hei',
#    'video': False,
#    'vote_average': 8.6,
#    'vote_count': 215},
#   {'adult': False,
#    'backdrop_path': '/3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg',
#    'genre_ids': [10749, 16],
#    'id': 372754,
#    'original_language': 'ja',
#    'original_title': '同級生',
#    'overview': 'Rihito Sajo, an honor student with a perfect score on the entrance exam and Hikaru Kusakabe, in a band and popular among girls, would have never crossed paths. Until one day they started talking at the practice for their school’s upcoming chorus festival. After school, the two meet regularly, as Hikaru helps Rihito to improve his singing skills. While they listen to each other’s voice and harmonize, their hearts start to beat together.',
#    'popularity': 11.288,
#    'poster_path': '/cIfRCA5wEvj9tApca4UDUagQEiM.jpg',
#    'release_date': '2016-02-20',
#    'title': 'Dou kyu sei – Classmates',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 263},
#   {'adult': False,
#    'backdrop_path': '/Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 129,
#    'original_language': 'ja',
#    'original_title': '千と千尋の神隠し',
#    'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#    'popularity': 64.948,
#    'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#    'release_date': '2001-07-20',
#    'title': 'Spirited Away',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 13595},
#   {'adult': False,
#    'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg',
#    'genre_ids': [18],
#    'id': 389,
#    'original_language': 'en',
#    'original_title': '12 Angry Men',
#    'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#    'popularity': 33.678,
#    'poster_path': '/ppd84D2i9W8jXmsyInGyihiSyqz.jpg',
#    'release_date': '1957-04-10',
#    'title': '12 Angry Men',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 6826},
#   {'adult': False,
#    'backdrop_path': '/mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg',
#    'genre_ids': [10749, 16, 18],
#    'id': 372058,
#    'original_language': 'ja',
#    'original_title': '君の名は。',
#    'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    'popularity': 74.434,
#    'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#    'release_date': '2016-08-26',
#    'title': 'Your Name.',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 9260},
#   {'adult': False,
#    'backdrop_path': '/TU9NIjwzjoKPwQHoHshkFcQUCG.jpg',
#    'genre_ids': [35, 53, 18],
#    'id': 496243,
#    'original_language': 'ko',
#    'original_title': '기생충',
#    'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#    'popularity': 52.624,
#    'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#    'release_date': '2019-05-30',
#    'title': 'Parasite',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 14779},
#   {'adult': False,
#    'backdrop_path': '/l6hQWH9eDksNJNiXWYRkWqikOdu.jpg',
#    'genre_ids': [14, 18, 80],
#    'id': 497,
#    'original_language': 'en',
#    'original_title': 'The Green Mile',
#    'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#    'popularity': 64.084,
#    'poster_path': '/velWPhVMQeQKcxggNEU8YmIo52R.jpg',
#    'release_date': '1999-12-10',
#    'title': 'The Green Mile',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 14675},
#   {'adult': False,
#    'backdrop_path': '/nMKdUUepR0i5zn0y1T4CsSB5chy.jpg',
#    'genre_ids': [18, 28, 80, 53],
#    'id': 155,
#    'original_language': 'en',
#    'original_title': 'The Dark Knight',
#    'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#    'popularity': 58.811,
#    'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#    'release_date': '2008-07-14',
#    'title': 'The Dark Knight',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 28656},
#   {'adult': False,
#    'backdrop_path': '/jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg',
#    'genre_ids': [10749],
#    'id': 724089,
#    'original_language': 'en',
#    'original_title': "Gabriel's Inferno: Part II",
#    'overview': "Professor Gabriel Emerson finally learns the truth about Julia Mitchell's identity, but his realization comes a moment too late. Julia is done waiting for the well-respected Dante specialist to remember her and wants nothing more to do with him. Can Gabriel win back her heart before she finds love in another's arms?",
#    'popularity': 14.833,
#    'poster_path': '/x5o8cLZfEXMoZczTYWLrUo1P7UJ.jpg',
#    'release_date': '2020-07-31',
#    'title': "Gabriel's Inferno: Part II",
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 1443},
#   {'adult': False,
#    'backdrop_path': '/w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg',
#    'genre_ids': [10749],
#    'id': 696374,
#    'original_language': 'en',
#    'original_title': "Gabriel's Inferno",
#    'overview': "An intriguing and sinful exploration of seduction, forbidden love, and redemption, Gabriel's Inferno is a captivating and wildly passionate tale of one man's escape from his own personal hell as he tries to earn the impossible--forgiveness and love.",
#    'popularity': 11.73,
#    'poster_path': '/oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg',
#    'release_date': '2020-05-29',
#    'title': "Gabriel's Inferno",
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 2300},
#   {'adult': False,
#    'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#    'genre_ids': [53, 80],
#    'id': 680,
#    'original_language': 'en',
#    'original_title': 'Pulp Fiction',
#    'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#    'popularity': 60.289,
#    'poster_path': '/fIE3lAGcZDV1G6XM5KmuWnNsPp1.jpg',
#    'release_date': '1994-09-10',
#    'title': 'Pulp Fiction',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 24122},
#   {'adult': False,
#    'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#    'genre_ids': [37],
#    'id': 429,
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'popularity': 46.676,
#    'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#    'release_date': '1966-12-23',
#    'title': 'The Good, the Bad and the Ugly',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 7003},
#   {'adult': False,
#    'backdrop_path': '/aQ7444JX7gefPhGJTlvilj3zG2S.jpg',
#    'genre_ids': [10402],
#    'id': 553512,
#    'original_language': 'ko',
#    'original_title': '번 더 스테이지: 더 무비',
#    'overview': 'A documentary following the worldwide famous music group BTS, as they tour the world and share their experience along with their beloved band friends and fans.',
#    'popularity': 14.026,
#    'poster_path': '/pJKy1yvnKh8UjcuYeG3Rt35xHFA.jpg',
#    'release_date': '2018-11-15',
#    'title': 'Burn the Stage: The Movie',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 372}],
#  'total_pages': 528,
#  'total_results': 10552}

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg',
#   'genre_ids': [10749, 18],
#   'id': 851644,
#   'original_language': 'ko',
#   'original_title': '20세기 소녀',
#   'overview': "Yeon-du asks her best friend Bora to collect all the information she can about Baek Hyun-jin while she is away in the U.S. for heart surgery. Bora decides to get close to Baek's best friend, Pung Woon-ho first. However, Bora's clumsy plan unfolds in an unexpected direction. In 1999, a year before the new century, Bora, who turns seventeen, falls into the fever of first love.",
#   'popularity': 170.54,
#   'poster_path': '/od22ftNnyag0TTxcnJhlsu3aLoU.jpg',
#   'release_date': '2022-10-06',
#   'title': '20th Century Girl',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 290},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 86.518,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 16988},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Framed in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 84.681,
#   'poster_path': '/hBcY0fE9pfXzvVaY4GKarweriG2.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 22748},
#  {'adult': False,
#   'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#   'genre_ids': [18, 80],
#   'id': 240,
#   'original_language': 'en',
#   'original_title': 'The Godfather Part II',
#   'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#   'popularity': 44.957,
#   'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#   'release_date': '1974-12-20',
#   'title': 'The Godfather Part II',
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 10293},
#  {'adult': False,
#   'backdrop_path': '/bxSBOAD8AuMHYMdW3jso9npAkgt.jpg',
#   'genre_ids': [10751, 18],
#   'id': 667257,
#   'original_language': 'es',
#   'original_title': 'Cosas imposibles',
#   'overview': 'Matilde is a woman who, after the death of her husband - a man who constantly abused her - finds her new best friend in Miguel, her young, insecure, disoriented and even dealer neighbor',
#   'popularity': 32.859,
#   'poster_path': '/t2Ew8NZ8Ci2kqmoecZUNQUFDJnQ.jpg',
#   'release_date': '2021-06-17',
#   'title': 'Impossible Things',
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 299},
#  {'adult': False,
#   'backdrop_path': '/vI3aUGTuRRdM7J78KIdW98LdxE5.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 23.31,
#   'poster_path': '/2CAL2433ZeIihfX1Hb2139CX0pW.jpg',
#   'release_date': '1995-10-19',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 3961},
#  {'adult': False,
#   'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#   'genre_ids': [18, 36, 10752],
#   'id': 424,
#   'original_language': 'en',
#   'original_title': "Schindler's List",
#   'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#   'popularity': 52.121,
#   'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#   'release_date': '1993-12-15',
#   'title': "Schindler's List",
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 13486},
#  {'adult': False,
#   'backdrop_path': '/aVFx1VtlOxR3v0ADEatalXOvwbu.jpg',
#   'genre_ids': [16, 14, 28],
#   'id': 620249,
#   'original_language': 'zh',
#   'original_title': '罗小黑战记',
#   'overview': 'In the bustling human world, spirits live peacefully with mankind. Luo Xiaohei, a young cat spirit, becomes a nomad after his forest home is destroyed. His natural talent soon attracts spirits and humans alike, but all of them have their own motivations.',
#   'popularity': 18.207,
#   'poster_path': '/aLv87NgRJUPkQ6sVLP72IisDdt4.jpg',
#   'release_date': '2019-08-27',
#   'title': 'The Legend of Hei',
#   'video': False,
#   'vote_average': 8.6,
#   'vote_count': 215},
#  {'adult': False,
#   'backdrop_path': '/3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg',
#   'genre_ids': [10749, 16],
#   'id': 372754,
#   'original_language': 'ja',
#   'original_title': '同級生',
#   'overview': 'Rihito Sajo, an honor student with a perfect score on the entrance exam and Hikaru Kusakabe, in a band and popular among girls, would have never crossed paths. Until one day they started talking at the practice for their school’s upcoming chorus festival. After school, the two meet regularly, as Hikaru helps Rihito to improve his singing skills. While they listen to each other’s voice and harmonize, their hearts start to beat together.',
#   'popularity': 11.288,
#   'poster_path': '/cIfRCA5wEvj9tApca4UDUagQEiM.jpg',
#   'release_date': '2016-02-20',
#   'title': 'Dou kyu sei – Classmates',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 263},
#  {'adult': False,
#   'backdrop_path': '/Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg',
#   'genre_ids': [16, 10751, 14],
#   'id': 129,
#   'original_language': 'ja',
#   'original_title': '千と千尋の神隠し',
#   'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#   'popularity': 64.948,
#   'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#   'release_date': '2001-07-20',
#   'title': 'Spirited Away',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 13595},
#  {'adult': False,
#   'backdrop_path': '/qqHQsStV6exghCM7zbObuYBiYxw.jpg',
#   'genre_ids': [18],
#   'id': 389,
#   'original_language': 'en',
#   'original_title': '12 Angry Men',
#   'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#   'popularity': 33.678,
#   'poster_path': '/ppd84D2i9W8jXmsyInGyihiSyqz.jpg',
#   'release_date': '1957-04-10',
#   'title': '12 Angry Men',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 6826},
#  {'adult': False,
#   'backdrop_path': '/mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg',
#   'genre_ids': [10749, 16, 18],
#   'id': 372058,
#   'original_language': 'ja',
#   'original_title': '君の名は。',
#   'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#   'popularity': 74.434,
#   'poster_path': '/q719jXXEzOoYaps6babgKnONONX.jpg',
#   'release_date': '2016-08-26',
#   'title': 'Your Name.',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 9260},
#  {'adult': False,
#   'backdrop_path': '/TU9NIjwzjoKPwQHoHshkFcQUCG.jpg',
#   'genre_ids': [35, 53, 18],
#   'id': 496243,
#   'original_language': 'ko',
#   'original_title': '기생충',
#   'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#   'popularity': 52.624,
#   'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#   'release_date': '2019-05-30',
#   'title': 'Parasite',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 14779},
#  {'adult': False,
#   'backdrop_path': '/l6hQWH9eDksNJNiXWYRkWqikOdu.jpg',
#   'genre_ids': [14, 18, 80],
#   'id': 497,
#   'original_language': 'en',
#   'original_title': 'The Green Mile',
#   'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#   'popularity': 64.084,
#   'poster_path': '/velWPhVMQeQKcxggNEU8YmIo52R.jpg',
#   'release_date': '1999-12-10',
#   'title': 'The Green Mile',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 14675},
#  {'adult': False,
#   'backdrop_path': '/nMKdUUepR0i5zn0y1T4CsSB5chy.jpg',
#   'genre_ids': [18, 28, 80, 53],
#   'id': 155,
#   'original_language': 'en',
#   'original_title': 'The Dark Knight',
#   'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#   'popularity': 58.811,
#   'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#   'release_date': '2008-07-14',
#   'title': 'The Dark Knight',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 28656},
#  {'adult': False,
#   'backdrop_path': '/jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg',
#   'genre_ids': [10749],
#   'id': 724089,
#   'original_language': 'en',
#   'original_title': "Gabriel's Inferno: Part II",
#   'overview': "Professor Gabriel Emerson finally learns the truth about Julia Mitchell's identity, but his realization comes a moment too late. Julia is done waiting for the well-respected Dante specialist to remember her and wants nothing more to do with him. Can Gabriel win back her heart before she finds love in another's arms?",
#   'popularity': 14.833,
#   'poster_path': '/x5o8cLZfEXMoZczTYWLrUo1P7UJ.jpg',
#   'release_date': '2020-07-31',
#   'title': "Gabriel's Inferno: Part II",
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 1443},
#  {'adult': False,
#   'backdrop_path': '/w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg',
#   'genre_ids': [10749],
#   'id': 696374,
#   'original_language': 'en',
#   'original_title': "Gabriel's Inferno",
#   'overview': "An intriguing and sinful exploration of seduction, forbidden love, and redemption, Gabriel's Inferno is a captivating and wildly passionate tale of one man's escape from his own personal hell as he tries to earn the impossible--forgiveness and love.",
#   'popularity': 11.73,
#   'poster_path': '/oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg',
#   'release_date': '2020-05-29',
#   'title': "Gabriel's Inferno",
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 2300},
#  {'adult': False,
#   'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#   'genre_ids': [53, 80],
#   'id': 680,
#   'original_language': 'en',
#   'original_title': 'Pulp Fiction',
#   'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#   'popularity': 60.289,
#   'poster_path': '/fIE3lAGcZDV1G6XM5KmuWnNsPp1.jpg',
#   'release_date': '1994-09-10',
#   'title': 'Pulp Fiction',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 24122},
#  {'adult': False,
#   'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#   'genre_ids': [37],
#   'id': 429,
#   'original_language': 'it',
#   'original_title': 'Il buono, il brutto, il cattivo',
#   'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#   'popularity': 46.676,
#   'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#   'release_date': '1966-12-23',
#   'title': 'The Good, the Bad and the Ugly',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 7003},
#  {'adult': False,
#   'backdrop_path': '/aQ7444JX7gefPhGJTlvilj3zG2S.jpg',
#   'genre_ids': [10402],
#   'id': 553512,
#   'original_language': 'ko',
#   'original_title': '번 더 스테이지: 더 무비',
#   'overview': 'A documentary following the worldwide famous music group BTS, as they tour the world and share their experience along with their beloved band friends and fans.',
#   'popularity': 14.026,
#   'poster_path': '/pJKy1yvnKh8UjcuYeG3Rt35xHFA.jpg',
#   'release_date': '2018-11-15',
#   'title': 'Burn the Stage: The Movie',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 372}]

# %%
 pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                           title  \
# 0   851644               20th Century Girl
# 1      238                   The Godfather
# 2      278        The Shawshank Redemption
# 3      240           The Godfather Part II
# 4   667257               Impossible Things
# 5    19404     Dilwale Dulhania Le Jayenge
# 6      424                Schindler's List
# 7   620249               The Legend of Hei
# 8   372754        Dou kyu sei – Classmates
# 9      129                   Spirited Away
# 10     389                    12 Angry Men
# 11  372058                      Your Name.
# 12  496243                        Parasite
# 13     497                  The Green Mile
# 14     155                 The Dark Knight
# 15  724089      Gabriel's Inferno: Part II
# 16  696374               Gabriel's Inferno
# 17     680                    Pulp Fiction
# 18     429  The Good, the Bad and the Ugly
# 19  553512       Burn the Stage: The Movie
#
#                                              overview release_date  \
# 0   Yeon-du asks her best friend Bora to collect a...   2022-10-06
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   Framed in the 1940s for the double murder of h...   1994-09-23
# 3   In the continuing saga of the Corleone crime f...   1974-12-20
# 4   Matilde is a woman who, after the death of her...   2021-06-17
# 5   Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# 6   The true story of how businessman Oskar Schind...   1993-12-15
# 7   In the bustling human world, spirits live peac...   2019-08-27
# 8   Rihito Sajo, an honor student with a perfect s...   2016-02-20
# 9   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 10  The defense and the prosecution have rested an...   1957-04-10
# 11  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 12  All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 13  A supernatural tale set on death row in a Sout...   1999-12-10
# 14  Batman raises the stakes in his war on crime. ...   2008-07-14
# 15  Professor Gabriel Emerson finally learns the t...   2020-07-31
# 16  An intriguing and sinful exploration of seduct...   2020-05-29
# 17  A burger-loving hit man, his philosophical par...   1994-09-10
# 18  While the Civil War rages on between the Union...   1966-12-23
# 19  A documentary following the worldwide famous m...   2018-11-15
#
#     popularity  vote_average  vote_count
# 0      170.540           8.7         290
# 1       86.518           8.7       16988
# 2       84.681           8.7       22748
# 3       44.957           8.6       10293
# 4       32.859           8.6         299
# 5       23.310           8.6        3961
# 6       52.121           8.6       13486
# 7       18.207           8.6         215
# 8       11.288           8.5         263
# 9       64.948           8.5       13595
# 10      33.678           8.5        6826
# 11      74.434           8.5        9260
# 12      52.624           8.5       14779
# 13      64.084           8.5       14675
# 14      58.811           8.5       28656
# 15      14.833           8.5        1443
# 16      11.730           8.5        2300
# 17      60.289           8.5       24122
# 18      46.676           8.5        7003
# 19      14.026           8.5         372

# %%
 pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg       [10749, 18]  851644
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]     238
# 2   False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg          [18, 80]     278
# 3   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]     240
# 4   False  /bxSBOAD8AuMHYMdW3jso9npAkgt.jpg       [10751, 18]  667257
# 5   False  /vI3aUGTuRRdM7J78KIdW98LdxE5.jpg   [35, 18, 10749]   19404
# 6   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 7   False  /aVFx1VtlOxR3v0ADEatalXOvwbu.jpg      [16, 14, 28]  620249
# 8   False  /3RMLbSEXOn1CzLoNT7xFeLfdxhq.jpg       [10749, 16]  372754
# 9   False  /Ab8mkHmkYADjU7wQiOkia9BzGvS.jpg   [16, 10751, 14]     129
# 10  False  /qqHQsStV6exghCM7zbObuYBiYxw.jpg              [18]     389
# 11  False  /mMtUybQ6hL24FXo0F3Z4j2KG7kZ.jpg   [10749, 16, 18]  372058
# 12  False   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg      [35, 53, 18]  496243
# 13  False  /l6hQWH9eDksNJNiXWYRkWqikOdu.jpg      [14, 18, 80]     497
# 14  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  [18, 28, 80, 53]     155
# 15  False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg           [10749]  724089
# 16  False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg           [10749]  696374
# 17  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]     680
# 18  False  /x4biAVdPVCghBlsVIzB6NmbghIz.jpg              [37]     429
# 19  False  /aQ7444JX7gefPhGJTlvilj3zG2S.jpg           [10402]  553512
#
#    original_language                   original_title  \
# 0                 ko                          20세기 소녀
# 1                 en                    The Godfather
# 2                 en         The Shawshank Redemption
# 3                 en            The Godfather Part II
# 4                 es                 Cosas imposibles
# 5                 hi     दिलवाले दुल्हनिया ले जायेंगे
# 6                 en                 Schindler's List
# 7                 zh                            罗小黑战记
# 8                 ja                              同級生
# 9                 ja                         千と千尋の神隠し
# 10                en                     12 Angry Men
# 11                ja                            君の名は。
# 12                ko                              기생충
# 13                en                   The Green Mile
# 14                en                  The Dark Knight
# 15                en       Gabriel's Inferno: Part II
# 16                en                Gabriel's Inferno
# 17                en                     Pulp Fiction
# 18                it  Il buono, il brutto, il cattivo
# 19                ko                   번 더 스테이지: 더 무비
#
#                                              overview  popularity  \
# 0   Yeon-du asks her best friend Bora to collect a...     170.540
# 1   Spanning the years 1945 to 1955, a chronicle o...      86.518
# 2   Framed in the 1940s for the double murder of h...      84.681
# 3   In the continuing saga of the Corleone crime f...      44.957
# 4   Matilde is a woman who, after the death of her...      32.859
# 5   Raj is a rich, carefree, happy-go-lucky second...      23.310
# 6   The true story of how businessman Oskar Schind...      52.121
# 7   In the bustling human world, spirits live peac...      18.207
# 8   Rihito Sajo, an honor student with a perfect s...      11.288
# 9   A young girl, Chihiro, becomes trapped in a st...      64.948
# 10  The defense and the prosecution have rested an...      33.678
# 11  High schoolers Mitsuha and Taki are complete s...      74.434
# 12  All unemployed, Ki-taek's family takes peculia...      52.624
# 13  A supernatural tale set on death row in a Sout...      64.084
# 14  Batman raises the stakes in his war on crime. ...      58.811
# 15  Professor Gabriel Emerson finally learns the t...      14.833
# 16  An intriguing and sinful exploration of seduct...      11.730
# 17  A burger-loving hit man, his philosophical par...      60.289
# 18  While the Civil War rages on between the Union...      46.676
# 19  A documentary following the worldwide famous m...      14.026
#
#                          poster_path release_date  \
# 0   /od22ftNnyag0TTxcnJhlsu3aLoU.jpg   2022-10-06
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2   /hBcY0fE9pfXzvVaY4GKarweriG2.jpg   1994-09-23
# 3   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 4   /t2Ew8NZ8Ci2kqmoecZUNQUFDJnQ.jpg   2021-06-17
# 5   /2CAL2433ZeIihfX1Hb2139CX0pW.jpg   1995-10-19
# 6   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 7   /aLv87NgRJUPkQ6sVLP72IisDdt4.jpg   2019-08-27
# 8   /cIfRCA5wEvj9tApca4UDUagQEiM.jpg   2016-02-20
# 9   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 10  /ppd84D2i9W8jXmsyInGyihiSyqz.jpg   1957-04-10
# 11  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-08-26
# 12  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 13  /velWPhVMQeQKcxggNEU8YmIo52R.jpg   1999-12-10
# 14  /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-14
# 15  /x5o8cLZfEXMoZczTYWLrUo1P7UJ.jpg   2020-07-31
# 16  /oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg   2020-05-29
# 17  /fIE3lAGcZDV1G6XM5KmuWnNsPp1.jpg   1994-09-10
# 18  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-23
# 19  /pJKy1yvnKh8UjcuYeG3Rt35xHFA.jpg   2018-11-15
#
#                              title  video  vote_average  vote_count
# 0                20th Century Girl  False           8.7         290
# 1                    The Godfather  False           8.7       16988
# 2         The Shawshank Redemption  False           8.7       22748
# 3            The Godfather Part II  False           8.6       10293
# 4                Impossible Things  False           8.6         299
# 5      Dilwale Dulhania Le Jayenge  False           8.6        3961
# 6                 Schindler's List  False           8.6       13486
# 7                The Legend of Hei  False           8.6         215
# 8         Dou kyu sei – Classmates  False           8.5         263
# 9                    Spirited Away  False           8.5       13595
# 10                    12 Angry Men  False           8.5        6826
# 11                      Your Name.  False           8.5        9260
# 12                        Parasite  False           8.5       14779
# 13                  The Green Mile  False           8.5       14675
# 14                 The Dark Knight  False           8.5       28656
# 15      Gabriel's Inferno: Part II  False           8.5        1443
# 16               Gabriel's Inferno  False           8.5        2300
# 17                    Pulp Fiction  False           8.5       24122
# 18  The Good, the Bad and the Ugly  False           8.5        7003
# 19       Burn the Stage: The Movie  False           8.5         372

# %%
 pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path    genre_ids      id  \
# 0  False  /rl7Jw8PjhSIjArOlDNv0JQPL1ZV.jpg  [10749, 18]  851644
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg     [18, 80]     238
#
#   original_language original_title  \
# 0                ko        20세기 소녀
# 1                en  The Godfather
#
#                                             overview  popularity  \
# 0  Yeon-du asks her best friend Bora to collect a...     170.540
# 1  Spanning the years 1945 to 1955, a chronicle o...      86.518
#
#                         poster_path release_date              title  video  \
# 0  /od22ftNnyag0TTxcnJhlsu3aLoU.jpg   2022-10-06  20th Century Girl  False
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14      The Godfather  False
#
#    vote_average  vote_count
# 0           8.7         290
# 1           8.7       16988

# %%
 pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                           title  \
# 0   851644               20th Century Girl
# 1      238                   The Godfather
# 2      278        The Shawshank Redemption
# 3      240           The Godfather Part II
# 4   667257               Impossible Things
# 5    19404     Dilwale Dulhania Le Jayenge
# 6      424                Schindler's List
# 7   620249               The Legend of Hei
# 8   372754        Dou kyu sei – Classmates
# 9      129                   Spirited Away
# 10     389                    12 Angry Men
# 11  372058                      Your Name.
# 12  496243                        Parasite
# 13     497                  The Green Mile
# 14     155                 The Dark Knight
# 15  724089      Gabriel's Inferno: Part II
# 16  696374               Gabriel's Inferno
# 17     680                    Pulp Fiction
# 18     429  The Good, the Bad and the Ugly
# 19  553512       Burn the Stage: The Movie
#
#                                              overview release_date  \
# 0   Yeon-du asks her best friend Bora to collect a...   2022-10-06
# 1   Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2   Framed in the 1940s for the double murder of h...   1994-09-23
# 3   In the continuing saga of the Corleone crime f...   1974-12-20
# 4   Matilde is a woman who, after the death of her...   2021-06-17
# 5   Raj is a rich, carefree, happy-go-lucky second...   1995-10-19
# 6   The true story of how businessman Oskar Schind...   1993-12-15
# 7   In the bustling human world, spirits live peac...   2019-08-27
# 8   Rihito Sajo, an honor student with a perfect s...   2016-02-20
# 9   A young girl, Chihiro, becomes trapped in a st...   2001-07-20
# 10  The defense and the prosecution have rested an...   1957-04-10
# 11  High schoolers Mitsuha and Taki are complete s...   2016-08-26
# 12  All unemployed, Ki-taek's family takes peculia...   2019-05-30
# 13  A supernatural tale set on death row in a Sout...   1999-12-10
# 14  Batman raises the stakes in his war on crime. ...   2008-07-14
# 15  Professor Gabriel Emerson finally learns the t...   2020-07-31
# 16  An intriguing and sinful exploration of seduct...   2020-05-29
# 17  A burger-loving hit man, his philosophical par...   1994-09-10
# 18  While the Civil War rages on between the Union...   1966-12-23
# 19  A documentary following the worldwide famous m...   2018-11-15
#
#     popularity  vote_average  vote_count
# 0      170.540           8.7         290
# 1       86.518           8.7       16988
# 2       84.681           8.7       22748
# 3       44.957           8.6       10293
# 4       32.859           8.6         299
# 5       23.310           8.6        3961
# 6       52.121           8.6       13486
# 7       18.207           8.6         215
# 8       11.288           8.5         263
# 9       64.948           8.5       13595
# 10      33.678           8.5        6826
# 11      74.434           8.5        9260
# 12      52.624           8.5       14779
# 13      64.084           8.5       14675
# 14      58.811           8.5       28656
# 15      14.833           8.5        1443
# 16      11.730           8.5        2300
# 17      60.289           8.5       24122
# 18      46.676           8.5        7003
# 19      14.026           8.5         372

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# ...
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_11148\2968228005.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                      title  \
# 0     851644          20th Century Girl
# 1        238              The Godfather
# 2        278   The Shawshank Redemption
# 3        240      The Godfather Part II
# 4     667257          Impossible Things
# ...      ...                        ...
# 8555   68728  Oz the Great and Powerful
# 8556    9982             Chicken Little
# 8557    9296                     S1m0ne
# 8558    6073                The Mexican
# 8559   45324                Casino Jack
#
#                                                overview release_date  \
# 0     Yeon-du asks her best friend Bora to collect a...   2022-10-06
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     Matilde is a woman who, after the death of her...   2021-06-17
# ...                                                 ...          ...
# 8555  Oscar Diggs, a small-time circus illusionist a...   2013-03-07
# 8556  When the sky really is falling and sanity has ...   2005-11-04
# 8557  The career of a disillusioned producer, who is...   2002-08-23
# 8558  Jerry Welbach, a reluctant bagman, has been gi...   2001-03-01
# 8559  Based on a true story, a hot shot Washington D...   2010-09-16
#
#       popularity  vote_average  vote_count
# 0        170.540           8.7         290
# 1         86.518           8.7       16988
# 2         84.681           8.7       22748
# 3         44.957           8.6       10293
# 4         32.859           8.6         299
# ...          ...           ...         ...
# 8555      35.706           5.9        6035
# 8556      35.353           5.9        3400
# 8557      12.787           5.9         774
# 8558      12.535           5.9        1211
# 8559       9.773           5.9         236
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
